# %% [markdown]
# <a href="https://colab.research.google.com/github/dilip-ksa/dilip_ml_pythondemo/blob/main/Day27_ML_journey_Matplotlib_Seaborn_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
################ Numpy and Pandas ###################
import numpy as np
import pandas as pd

arr = np.array([10,20,30,40]) # array element separated by space
print(type(arr))
print(arr)
# Out:
# <class 'numpy.ndarray'>
# [10 20 30 40]

# %%
###### Matplotlib & Seaborn ###############
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins_data = sns.load_dataset('penguins')
type(penguins_data)
# Out:
# pandas.core.frame.DataFrame

# %%
penguins_data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins_data.species.nunique()
penguins_data['species'].nunique()
# Out:
# 3

# %%
penguins_data.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins_data.species.value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins_data.island.nunique()
# Out:
# 3

# %%
penguins_data.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
penguins_data.island.value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
############# scatter plots  ####################
sns.scatterplot(data=penguins_data, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins_data, x='flipper_length_mm', y='body_mass_g')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins_data, x='flipper_length_mm', y='body_mass_g', hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
island_colors = {'Torgersen':'red', 'Biscoe':'blue', 'Dream':'green'}
sns.scatterplot(data=penguins_data, x='flipper_length_mm', y='body_mass_g', hue='island', palette=island_colors)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
# set styles in seaborn darkgrip, whitegrid, dard, white, ticks
sns.set_style('whitegrid')
sns.scatterplot(data=penguins_data, x='flipper_length_mm', y='body_mass_g', hue='island', palette=island_colors)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
# set context to set font size : paper, notebook, talk, poster
sns.set_context('notebook')
sns.scatterplot(data=penguins_data, x='flipper_length_mm', y='body_mass_g', hue='island', palette=island_colors)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
# Scatter plot on categorical data
sns.scatterplot(data=penguins_data, x='species', y='body_mass_g', hue='island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Strip plot on categorical data
sns.stripplot(data=penguins_data, x='species', y='body_mass_g', hue='island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Strip plot on categorical data
sns.stripplot(data=penguins_data, x='species', y='body_mass_g', hue='island', dodge=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Swarm trip plot on categorical data
sns.swarmplot(data=penguins_data, x='species', y='body_mass_g', hue='island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Histogram plot on categorical data
sns.histplot(data=penguins_data, x='body_mass_g', hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
# Histogram plot on categorical data
sns.histplot(data=penguins_data, x='body_mass_g', hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.regplot(data=penguins_data, x='flipper_length_mm', y='body_mass_g')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.regplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# line plot
sns.set_context('notebook')
sns.set_style('darkgrid')
sns.lineplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# line plot
sns.set_context('notebook')
sns.set_style('darkgrid')
sns.lineplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# joint plot
sns.jointplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm')

# %%
# joint plot
sns.jointplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', hue='species')

# %%
# joint plot
sns.jointplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', hue='sex')

# %%
# joint plot with hue and kind
sns.jointplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', hue='species', kind='kde')

# %%
# bar plot
sns.barplot(data=penguins_data, x='species', y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# bar plot
sns.barplot(data=penguins_data, x='species', y='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# bar plot
sns.barplot(data=penguins_data, x='species', y='body_mass_g', hue='sex', palette='rocket')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# bar plot
sns.barplot(data=penguins_data, x='species', y='body_mass_g', hue='sex', palette=['blue','pink'], )
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# ecdf plot
sns.ecdfplot(data=penguins_data, x='body_mass_g')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Proportion'>

# %%
# cat plot
sns.catplot(data=penguins_data, x='species', y='body_mass_g')

# %%
#count plot
sns.countplot(data=penguins_data, x='species', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# dis plot
sns.displot(data=penguins_data, x='body_mass_g', hue='species')

# %%
# dist plot
sns.displot(data=penguins_data, x='body_mass_g', hue='species', kind='kde')

# %%
# dog plot
sns.dogplot(data=penguins_data, x='species', y='body_mass_g')

# %%
# kde plot
sns.kdeplot(data=penguins_data, x='body_mass_g', hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
# lm plot
sns.lmplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', hue='species')

# %%
# pair plot
sns.pairplot(data=penguins_data, hue='species')

# %%
# pal plot
sns.palplot(sns.color_palette('rocket'), size=2)

# %%
# point plot
sns.pointplot(data=penguins_data, x='species', y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# reg plot
sns.regplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# rel plot
sns.relplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', hue='species')

# %%
# resid plot
sns.residplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# rug plot
sns.rugplot(data=penguins_data, x='body_mass_g')
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
# violin plot
sns.violinplot(data=penguins_data, x='species', y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# misc plot
sns.jointplot(data=penguins_data, x='body_mass_g', y='flipper_length_mm', kind='kde')
